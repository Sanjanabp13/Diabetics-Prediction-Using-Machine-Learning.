# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
diab=pd.read_csv('diabetes_new.csv')

# %%
diab
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
diab.isnull()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0           False    False          False          False    False  False
# 1           False    False          False          False    False  False
# 2           False    False          False          False    False  False
# 3           False    False          False          False    False  False
# 4           False    False          False          False    False  False
# ...           ...      ...            ...            ...      ...    ...
# 1995        False    False          False          False    False  False
# 1996        False    False          False          False    False  False
# 1997        False    False          False          False    False  False
# 1998        False    False          False          False    False  False
# 1999        False    False          False          False    False  False
#
#       DiabetesPedigreeFunction    Age  Outcome
# ...

# %%
diab.isnull().any().sum()
# Out:
# 0

# %%
diab.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diab['Pregnancies'].value_counts().plot.bar(color=['yellow','orange','red'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(20,8))
diab['Glucose'].value_counts().plot.bar(color=['green','orange','red'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(20,8))
diab['BloodPressure'].value_counts().plot.bar(color=['violet','orange','red'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(20,8))
diab['SkinThickness'].value_counts().plot.bar(color=['black','orange','red'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(14,6))
diab['Insulin'].value_counts().plot.bar(color=['blue','pink','red'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(14,6))
diab['BMI'].value_counts().plot.bar(color=['blue','pink','yellow'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(14,6))
diab['DiabetesPedigreeFunction'].value_counts().plot.bar(color=['blue','red','yellow'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(14,6))
diab['Age'].value_counts().plot.bar(color=['green','red','yellow'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=1)
plt.show()

# %%
plt.figure(figsize=(14,6))
diab['Outcome'].value_counts().plot.bar(color=['green','blue','black'])
plt.title('diabetics data',size=18)
plt.xlabel('no of rows',size=12)
plt.ylabel('no of columns',size=14)
plt.xticks(rotation=0)
plt.show()

# %%
diab.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x=diab[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin']]

# %%
x
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0               2      138             62             35        0
# 1               0       84             82             31      125
# 2               0      145              0              0        0
# 3               0      135             68             42      250
# 4               1      139             62             41      480
# ...           ...      ...            ...            ...      ...
# 1995            2       75             64             24       55
# 1996            8      179             72             42      130
# 1997            6       85             78              0        0
# 1998            0      129            110             46      130
# 1999            2       81             72             15       76
#
# [2000 rows x 5 columns]

# %%
y=diab[['BMI','DiabetesPedigreeFunction','Age', 'Outcome']]

# %%
y
# Out:
#        BMI  DiabetesPedigreeFunction  Age  Outcome
# 0     33.6                     0.127   47        1
# 1     38.2                     0.233   23        0
# 2     44.2                     0.630   31        1
# 3     42.3                     0.365   24        1
# 4     40.7                     0.536   21        0
# ...    ...                       ...  ...      ...
# 1995  29.7                     0.370   33        0
# 1996  32.7                     0.719   36        1
# 1997  31.2                     0.382   42        0
# 1998  67.1                     0.319   26        1
# 1999  30.1                     0.547   25        0
#
# [2000 rows x 4 columns]

# %%
diab=x.append(y)

# %%
diab
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             2.0    138.0           62.0           35.0      0.0   NaN
# 1             0.0     84.0           82.0           31.0    125.0   NaN
# 2             0.0    145.0            0.0            0.0      0.0   NaN
# 3             0.0    135.0           68.0           42.0    250.0   NaN
# 4             1.0    139.0           62.0           41.0    480.0   NaN
# ...           ...      ...            ...            ...      ...   ...
# 1995          NaN      NaN            NaN            NaN      NaN  29.7
# 1996          NaN      NaN            NaN            NaN      NaN  32.7
# 1997          NaN      NaN            NaN            NaN      NaN  31.2
# 1998          NaN      NaN            NaN            NaN      NaN  67.1
# 1999          NaN      NaN            NaN            NaN      NaN  30.1
#
#       DiabetesPedigreeFunction   Age  Outcome
# 0                          NaN   NaN      NaN
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    2000 non-null   int64
#  1   Glucose        2000 non-null   int64
#  2   BloodPressure  2000 non-null   int64
#  3   SkinThickness  2000 non-null   int64
#  4   Insulin        2000 non-null   int64
# dtypes: int64(5)
# memory usage: 78.2 KB

# %%
x.isnull()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0           False    False          False          False    False
# 1           False    False          False          False    False
# 2           False    False          False          False    False
# 3           False    False          False          False    False
# 4           False    False          False          False    False
# ...           ...      ...            ...            ...      ...
# 1995        False    False          False          False    False
# 1996        False    False          False          False    False
# 1997        False    False          False          False    False
# 1998        False    False          False          False    False
# 1999        False    False          False          False    False
#
# [2000 rows x 5 columns]

# %%
y.isnull()
# Out:
#         BMI  DiabetesPedigreeFunction    Age  Outcome
# 0     False                     False  False    False
# 1     False                     False  False    False
# 2     False                     False  False    False
# 3     False                     False  False    False
# 4     False                     False  False    False
# ...     ...                       ...    ...      ...
# 1995  False                     False  False    False
# 1996  False                     False  False    False
# 1997  False                     False  False    False
# 1998  False                     False  False    False
# 1999  False                     False  False    False
#
# [2000 rows x 4 columns]

# %%
diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   float64
#  1   Glucose                   2000 non-null   float64
#  2   BloodPressure             2000 non-null   float64
#  3   SkinThickness             2000 non-null   float64
#  4   Insulin                   2000 non-null   float64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   float64
#  8   Outcome                   2000 non-null   float64
# dtypes: float64(9)
# memory usage: 312.5 KB
